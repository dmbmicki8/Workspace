# %%
import pandas as pd

# %% [markdown]
# ### Data Types: all objects in python have a type. You can check the type by using the _type()_ function. Here are a few standard ones

# %%
type(1.5)
# Out:
# float

# %%
type(3)
# Out:
# int

# %%
type('abc')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ### You can convert between types

# %%
float(1)
# Out:
# 1.0

# %%
str(1)
# Out:
# '1'

# %%
int('9')
# Out:
# 9

# %%
int(9.9)
# Out:
# 9

# %% [markdown]
# ### DataFrames also have a type

# %%
accidents = pd.read_csv('../data/Traffic_Accidents.csv')

# %%
type(accidents)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### And each column has a type

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28173 entries, 0 to 28172
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Accident Number             28173 non-null  int64
#  1   Date and Time               28173 non-null  object
#  2   Number of Motor Vehicles    28173 non-null  float64
#  3   Number of Injuries          28173 non-null  float64
#  4   Number of Fatalities        28173 non-null  int64
#  5   Property Damage             2588 non-null   object
#  6   Hit and Run                 28169 non-null  object
#  7   Reporting Officer           28172 non-null  float64
#  8   Collision Type Code         28172 non-null  float64
#  9   Collision Type Description  28172 non-null  object
#  10  Weather Code                23634 non-null  float64
#  11  Weather Description         23634 non-null  object
#  12  Illumination Code           28127 non-null  float64
#  13  Illumination Description    28127 non-null  object
#  14  Harmful Code                28173 non-null  object
#  15  Harmful Description         27774 non-null  object
#  16  Street Address              28173 non-null  object
#  17  City                        28173 non-null  object
#  18  State                       28173 non-null  object
#  19  ZIP                         28162 non-null  float64
#  20  RPA                         28163 non-null  float64
#  21  Precinct                    28163 non-null  object
#  22  Latitude                    28115 non-null  float64
#  23  Longitude                   28115 non-null  float64
#  24  Mapped Location             28115 non-null  object
#  25  date                        28173 non-null  object
# dtypes: float64(10), int64(2), object(14)
# memory usage: 5.6+ MB

# %%
accidents.dtypes
# Out:
# Accident Number                 int64
# Date and Time                  object
# Number of Motor Vehicles      float64
# Number of Injuries            float64
# Number of Fatalities            int64
# Property Damage                object
# Hit and Run                    object
# Reporting Officer             float64
# Collision Type Code           float64
# Collision Type Description     object
# Weather Code                  float64
# Weather Description            object
# Illumination Code             float64
# Illumination Description       object
# Harmful Code                   object
# Harmful Description            object
# Street Address                 object
# City                           object
# State                          object
# ZIP                           float64
# RPA                           float64
# Precinct                       object
# Latitude                      float64
# Longitude                     float64
# Mapped Location                object
# date                           object
# dtype: object

# %%
accidents.head()
# Out:
#    Accident Number        Date and Time  Number of Motor Vehicles  \
# 0      20200000247  2020-01-01 00:25:00                       2.0
# 1      20200000511  2020-01-01 00:30:00                       2.0
# 2      20200000105  2020-01-01 00:35:00                       2.0
# 3      20200000203  2020-01-01 01:03:00                       2.0
# 4      20200000229  2020-01-01 01:25:00                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 0.0                     0             NaN        True
# 1                 0.0                     0             NaN        True
# 2                 2.0                     0             NaN       False
# 3                 0.0                     0             NaN       False
# 4                 1.0                     0             NaN       False
#
#    Reporting Officer  Collision Type Code  Collision Type Description  ...  \
# 0           109543.0                  5.0  SIDESWIPE - SAME DIRECTION  ...
# 1           279217.0                 11.0               Front to Rear  ...
# 2           110062.0                  4.0                       ANGLE  ...
# 3           226175.0                 11.0               Front to Rear  ...
# 4           224437.0                 11.0               Front to Rear  ...
#
#            Street Address       City  State      ZIP     RPA Precinct  \
# 0    6TH AVN & MADISON ST  NASHVILLE     TN  37208.0  4305.0    NORTH
# 1  9TH AVN & JEFFERSON ST  NASHVILLE     TN  37208.0  4239.0    NORTH
# 2            MM 47 1 I 24  NASHVILLE     TN  37207.0  1904.0   CENTRA
# 3           MM 200 6 I 40  NASHVILLE     TN  37209.0  4708.0     WEST
# 4   VICTORY AV & S 1ST ST  NASHVILLE     TN  37213.0  1101.0   CENTRA
#
#   Latitude Longitude           Mapped Location        date
# 0  36.1750  -86.7894   POINT (-86.7894 36.175)  2020-01-01
# 1  36.1730  -86.7924   POINT (-86.7924 36.173)  2020-01-01
# 2  36.1870  -86.7760    POINT (-86.776 36.187)  2020-01-01
# 3  36.1261  -86.9040   POINT (-86.904 36.1261)  2020-01-01
# 4  36.1649  -86.7702  POINT (-86.7702 36.1649)  2020-01-01
#
# [5 rows x 26 columns]

# %% [markdown]
# ### One data type you will encounter is a `datetime`

# %% [markdown]
# ### The `Date and Time` column in the `accidents` dataframe is treated as an `object` but we can convert it to a different type, such as a `datetime`

# %%
# Let's convert the 'Date and Time' column to a datetime and assign it back to itself
accidents['Date and Time'] = pd.to_datetime(accidents['Date and Time'])

# pd.to_datetime will infer the different date and time components of the string.
# If the datetime is in a strange format or you want to be explicit you can use the 'format' argument
# You will have to use datetime symbols: 
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# It will take a second to run...

# %%
# Now the column is a datetime64[ns]
accidents.dtypes
# Out:
# Accident Number                        int64
# Date and Time                 datetime64[ns]
# Number of Motor Vehicles             float64
# Number of Injuries                   float64
# Number of Fatalities                   int64
# Property Damage                       object
# Hit and Run                           object
# Reporting Officer                    float64
# Collision Type Code                  float64
# Collision Type Description            object
# Weather Code                         float64
# Weather Description                   object
# Illumination Code                    float64
# Illumination Description              object
# Harmful Code                          object
# Harmful Description                   object
# Street Address                        object
# City                                  object
# State                                 object
# ZIP                                  float64
# RPA                                  float64
# Precinct                              object
# Latitude                             float64
# Longitude                            float64
# Mapped Location                       object
# date                                  object
# dtype: object

# %%
# The values in the Date and Time column look different now
accidents.head()
# Out:
#    Accident Number       Date and Time  Number of Motor Vehicles  \
# 0      20200000247 2020-01-01 00:25:00                       2.0
# 1      20200000511 2020-01-01 00:30:00                       2.0
# 2      20200000105 2020-01-01 00:35:00                       2.0
# 3      20200000203 2020-01-01 01:03:00                       2.0
# 4      20200000229 2020-01-01 01:25:00                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 0.0                     0             NaN        True
# 1                 0.0                     0             NaN        True
# 2                 2.0                     0             NaN       False
# 3                 0.0                     0             NaN       False
# 4                 1.0                     0             NaN       False
#
#    Reporting Officer  Collision Type Code  Collision Type Description  ...  \
# 0           109543.0                  5.0  SIDESWIPE - SAME DIRECTION  ...
# 1           279217.0                 11.0               Front to Rear  ...
# 2           110062.0                  4.0                       ANGLE  ...
# 3           226175.0                 11.0               Front to Rear  ...
# 4           224437.0                 11.0               Front to Rear  ...
#
#            Street Address       City  State      ZIP     RPA Precinct  \
# 0    6TH AVN & MADISON ST  NASHVILLE     TN  37208.0  4305.0    NORTH
# 1  9TH AVN & JEFFERSON ST  NASHVILLE     TN  37208.0  4239.0    NORTH
# 2            MM 47 1 I 24  NASHVILLE     TN  37207.0  1904.0   CENTRA
# 3           MM 200 6 I 40  NASHVILLE     TN  37209.0  4708.0     WEST
# 4   VICTORY AV & S 1ST ST  NASHVILLE     TN  37213.0  1101.0   CENTRA
#
#   Latitude Longitude           Mapped Location        date
# 0  36.1750  -86.7894   POINT (-86.7894 36.175)  2020-01-01
# 1  36.1730  -86.7924   POINT (-86.7924 36.173)  2020-01-01
# 2  36.1870  -86.7760    POINT (-86.776 36.187)  2020-01-01
# 3  36.1261  -86.9040   POINT (-86.904 36.1261)  2020-01-01
# 4  36.1649  -86.7702  POINT (-86.7702 36.1649)  2020-01-01
#
# [5 rows x 26 columns]

# %%
# And we can see each value is a timestamp
accidents.loc[0, 'Date and Time']
# Out:
# Timestamp('2020-01-01 00:25:00')

# %% [markdown]
# ### Once you have a `datetime` object, you can pull out [individual parts](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html)
# - Use `.dt` to specify a datetime attribute/function and then what you want to pull out
# - Pull out the month from the 'Date and Time' column and save it to a new column called 'month'

# %%
accidents['month'] = accidents['Date and Time'].dt.month
accidents.head()
# Out:
#    Accident Number       Date and Time  Number of Motor Vehicles  \
# 0      20200000247 2020-01-01 00:25:00                       2.0
# 1      20200000511 2020-01-01 00:30:00                       2.0
# 2      20200000105 2020-01-01 00:35:00                       2.0
# 3      20200000203 2020-01-01 01:03:00                       2.0
# 4      20200000229 2020-01-01 01:25:00                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 0.0                     0             NaN        True
# 1                 0.0                     0             NaN        True
# 2                 2.0                     0             NaN       False
# 3                 0.0                     0             NaN       False
# 4                 1.0                     0             NaN       False
#
#    Reporting Officer  Collision Type Code  Collision Type Description  ...  \
# 0           109543.0                  5.0  SIDESWIPE - SAME DIRECTION  ...
# 1           279217.0                 11.0               Front to Rear  ...
# 2           110062.0                  4.0                       ANGLE  ...
# 3           226175.0                 11.0               Front to Rear  ...
# 4           224437.0                 11.0               Front to Rear  ...
#
#         City State      ZIP     RPA Precinct Latitude Longitude  \
# 0  NASHVILLE    TN  37208.0  4305.0    NORTH  36.1750  -86.7894
# 1  NASHVILLE    TN  37208.0  4239.0    NORTH  36.1730  -86.7924
# 2  NASHVILLE    TN  37207.0  1904.0   CENTRA  36.1870  -86.7760
# 3  NASHVILLE    TN  37209.0  4708.0     WEST  36.1261  -86.9040
# 4  NASHVILLE    TN  37213.0  1101.0   CENTRA  36.1649  -86.7702
#
#             Mapped Location        date  month
# 0   POINT (-86.7894 36.175)  2020-01-01      1
# 1   POINT (-86.7924 36.173)  2020-01-01      1
# 2    POINT (-86.776 36.187)  2020-01-01      1
# 3   POINT (-86.904 36.1261)  2020-01-01      1
# 4  POINT (-86.7702 36.1649)  2020-01-01      1
#
# [5 rows x 27 columns]

# %% [markdown]
# #### What is the maximum number of cars involved in a single accident in July?
# - subset the `accidents` DataFrame to get the July accidents
# - find the maximum `Number of Motor Vehicles` for accidents that happened in July

# %%
july_accidents = accidents[accidents['month']==7]
july_accidents.head()
# Out:
#        Accident Number       Date and Time  Number of Motor Vehicles  \
# 11794      20200438614 2020-07-01 00:00:00                       2.0
# 11795      20200436762 2020-07-01 00:00:00                       1.0
# 11796      20200436723 2020-07-01 00:00:00                       1.0
# 11797      20200436661 2020-07-01 00:03:00                       1.0
# 11798      20200436745 2020-07-01 00:15:00                       2.0
#
#        Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 11794                 0.0                     0             NaN        True
# 11795                 0.0                     0            True        True
# 11796                 0.0                     0            True        True
# 11797                 0.0                     0            True       False
# 11798                 0.0                     0             NaN        True
#
#        Reporting Officer  Collision Type Code  \
# 11794           256495.0                  9.0
# 11795           409221.0                  0.0
# 11796           409208.0                  9.0
# 11797           256502.0                  0.0
# 11798           332215.0                 11.0
#
#                     Collision Type Description  ...       City State      ZIP  \
# 11794                                  UNKNOWN  ...  NASHVILLE    TN  37208.0
# 11795  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...    ANTIOCH    TN  37013.0
# 11796                                  UNKNOWN  ...  NASHVILLE    TN  37221.0
# 11797  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...    MADISON    TN  37115.0
# 11798                            Front to Rear  ...  NASHVILLE    TN  37209.0
#
#            RPA Precinct Latitude Longitude           Mapped Location  \
# 11794   4487.0    NORTH  36.1875  -86.8169  POINT (-86.8169 36.1875)
# 11795   8765.0    SOUTH  36.1969  -86.7929  POINT (-86.7929 36.1969)
# 11796   4806.0     WEST  36.0950  -86.9373   POINT (-86.9373 36.095)
# 11797   1627.0   MADISO  36.2619  -86.7033  POINT (-86.7033 36.2619)
# 11798  52040.0     WEST  36.1549  -86.8305  POINT (-86.8305 36.1549)
#
#              date  month
# 11794  2020-07-01      7
# 11795  2020-07-01      7
# 11796  2020-07-01      7
# 11797  2020-07-01      7
# 11798  2020-07-01      7
#
# [5 rows x 27 columns]

# %%
july_accidents['Number of Motor Vehicles'].max()
# Out:
# 7.0

# %%
july_accidents.nlargest(1, 'Number of Motor Vehicles')
# Out:
#        Accident Number       Date and Time  Number of Motor Vehicles  \
# 11929      20200442999 2020-07-04 00:46:00                       7.0
#
#        Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 11929                 3.0                     0            True       False
#
#        Reporting Officer  Collision Type Code Collision Type Description  ...  \
# 11929           320578.0                 98.0                      OTHER  ...
#
#             City State      ZIP     RPA Precinct Latitude Longitude  \
# 11929  NASHVILLE    TN  37211.0  8711.0    SOUTH  36.0667  -86.7179
#
#                 Mapped Location        date  month
# 11929  POINT (-86.7179 36.0667)  2020-07-04      7
#
# [1 rows x 27 columns]

# %%
# How many accidents happened in December?
(accidents['month']==12).sum()
# Out:
# np.int64(1515)

# %% [markdown]
# ### There are [many different attributes associated with datetimes](https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587)

# %%
accidents['Date and Time'].dt.time.head()
# Out:
# 0    00:25:00
# 1    00:30:00
# 2    00:35:00
# 3    01:03:00
# 4    01:25:00
# Name: Date and Time, dtype: object

# %%
accidents['Date and Time'].dt.date.head()
# Out:
# 0    2020-01-01
# 1    2020-01-01
# 2    2020-01-01
# 3    2020-01-01
# 4    2020-01-01
# Name: Date and Time, dtype: object

# %%
accidents['Date and Time'].dt.weekday.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Date and Time, dtype: int32

# %%
accidents['Date and Time'].dt.is_leap_year.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Date and Time, dtype: bool

# %% [markdown]
# ### You can use comparison symbols on `datetime` objects as well

# %%
# How many accidents happened before March 3
sum(accidents['Date and Time'] < '03/03/2019')

# Note: You have to input the comparison value as a string,
# but the format can vary and pandas will attempt to infer the format.
# Try putting in different formats and rerunning this cell.
# Out:
# 0

# %% [markdown]
# ### You can also perform calculations on `datetime` objects

# %%
# How long between the 1st and 101th accident?
accidents = accidents.sort_values('Date and Time')
accidents.loc[100, 'Date and Time'] - accidents.loc[0, 'Date and Time']

# It appears as a Timedelta, or a change in time
# Out:
# Timedelta('1 days 13:53:00')

# %% [markdown]
# # End of Instruction

# %% [markdown]
# ### Use PGAdmin to get the player info for all players, if they are in the Hall of fame, also pull that data.
# ### Save those results as a .csv and read them into this notebook in the cell below

# %%
baseball = pd.read_csv('../data/baseball.csv')

baseball.columns
# Out:
# Index(['playerid,"birthyear","birthmonth","birthday","birthcountry","birthstate","birthcity","deathyear","deathmonth","deathday","deathcountry","deathstate","deathcity","namefirst","namelast","namegiven","weight","height","bats","throws","debut","finalgame","retroid","bbrefid","yearid","votedby","ballots","needed","votes","inducted","category","needed_note"'], dtype='object')

# %% [markdown]
# ### Convert the debut and final game info into Datetime

# %%
baseball["debut"] = pd.to_datetime(baseball["debut"])
baseball['finalgame']= pd.to_datetime(baseball['finalgame'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'debut'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 baseball["debut"] = pd.to_datetime(baseball["debut"])
#       2 baseball['finalgame']= pd.to_datetime(baseball['finalgame'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'debut'

# %% [markdown]
# ### Find the difference in bebut and final game for all players

# %%
baseball['difference'] =baseball['finalgame']-baseball['debut']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'finalgame'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 baseball['difference'] =baseball['finalgame']-baseball['debut']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'finalgame'

# %% [markdown]
# ### Next compare that difference among all players, hall of fame players, and players not in the hall of fame
